# %%
from pyecharts.charts import Sunburst
from pyecharts import options as opts

# %%
data = [
        {
        "name": "$260.5B \n 卫星产业",
        "itemStyle": {"color": "#da1d23"},
        "children": [
            {
                "name": "$97.7B \n 电视",'value':97.7,"itemStyle": {"color": "#dd4c51"},
            },
            {
                "name": "$17.4B \n 固定卫星（FSS）",'value':17.4,"itemStyle": {"color": "#c94a44"},
            },
            {
                "name": "$5B 广播卫星",'value':5,"itemStyle": {"color": "#f2684b"},

            },
            
            {
                "name": "$3.6B 移动卫星（MSS）",'value':3.6,"itemStyle": {"color": "#E0115F"},
            },
            
            {
                "name": "$2B 商业遥感卫星",'value':2,"itemStyle": {"color": "#F33A6A"},
            },
            
            {
                "name": "$2B 宽带传输卫星",'value':2,"itemStyle": {"color": "#E37383"},
            },
            
            {
                "name": "$2B 宽带传输卫星",'value':2,"itemStyle": {"color": "#E37383"},
            },
            
            {
                "name": "$60.8B \n 卫星地面设备",'value':60.8,"itemStyle": {"color": "#6495ED"},
                "children": [
                    
                    {
                        'name':'$32B \n 个人导航设备和车载系统','value':32, 'itemStyle':{'color':'#5D3FD3'},
                    },
                    {
                        'name':'$18.5B \n 卫星电视天线 \n 卫星移动终端','value':18.5,'itemStyle':{'color':'#3F00FF'},
                    },
                        
                    {
                    "name":'$10.3B \n 网络设备','value':10.3,'itemStyle':{'color':'#0096FF'},
                    }
                   
                ],
                 
            },
            {
                "name":'$52.6B \n GNSS芯片 \n 及相关组件','value':52.6,"itemStyle":{'color':"#A3E4D7"},
                'children':[
                    {
                        'name':'$29.6B \n GNSS芯片','value':29.6, 'itemStyle':{'color':'#76D7C4'},
                    },
                      {
                        'name':'$17B \n 交通信息服务','value':17, 'itemStyle':{'color':'#73C6B6'},
                    },
                     {
                        'name':'$3B 测量设备','value':3, 'itemStyle':{'color':'#7DCEA0'},
                    },
                      {
                        'name':'$3B GNSS地面设备','value':3, 'itemStyle':{'color':'#58D68D'},
                    },
                ]
            },
            
            {
              "name":'$13.9B \n 卫星制造','value':13.9,"itemStyle":{'color':"#BB8FCE"},  
            },
            
             {
              "name":'$5.5B 发射服务','value':5.5,"itemStyle":{'color':"#F4D03F"},  
            },
             
        ],
    },
    
    
    {
        "name": "非卫星行业",
        "itemStyle": {"color": "#da0d68"},
        "children": [
            {"name": "$82.9B 政府预算项目", "value": 82.9, "itemStyle": {"color": "#F0B27A "},
            "children": [
                 {"name": "$47.5B 美国政府","value": 47.5, "itemStyle": {"color": "#EB984E"},},
                 {"name": "$10.8B 中国政府","value": 10.8, "itemStyle": {"color": "#E67E22"},},
                 {"name": "$10B 欧洲政府","value": 10, "itemStyle": {"color": "#CA6F1E"},},
                 {"name": "$4.3B 印度政府","value": 4.3, "itemStyle": {"color": "#D35400"},},
                 {"name": "$3.6B 俄罗斯政府","value": 3.6, "itemStyle": {"color": "#BA4A00"},},
                 {"name": "$3.5B 日本政府","value": 3.5, "itemStyle": {"color": "#E59866"},},
                 {"name": "$3.2B 其他国家","value": 3.2, "itemStyle": {"color": "#E59866"},},
            ],
           
            },
            {
              "name":'$1.1B 载人航天','value':1.1,"itemStyle":{'color':"#2E4053"},  
            },
        ],
    },

]

c = (
    Sunburst(init_opts=opts.InitOpts(width="1000px", height="1000px"))
    .add(
        "",
        data_pair=data,
        highlight_policy="ancestor",
        radius=[0, "100%"],
        sort_="null",
        levels=[
            {},
            {
                "r0": "15%",
                "r": "25%",
                "itemStyle": {"borderWidth": 2},
                "label": {"rotate": "tangential"},
            },
            {"r0": "25%", "r": "60%", "label": {"align": "center"}},
            {
                "r0": "60%",
                "r": "97%",
                "label": {"position": "center", "padding": 3, "silent": False},
                "itemStyle": {"borderWidth": 1},
            },
   
            
            
        ],
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="世界卫星经济旭日图"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))

)
c.render()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="add359ddce4242e29182a26874d5a415" style="width:1000px; height:1000px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_add359ddce4242e29182a26874d5a415 = echarts.init(
#                     document.getElementById('add359ddce4242e29182a26874d5a415'), 'white', {renderer: 'canvas'});
#                 var option_add359ddce4242e29182a26874d5a415 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
